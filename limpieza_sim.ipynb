# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib as plt
import sklearn as sk
import scipy.stats as stats
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('df.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# model                object
# sim                  object
# additional_data      object
# 3G                   object
# 4G                   object
# 5G                   object
# Wi-Fi                object
# VoLTE                object
# Vo5G                 object
# NFC                  object
# extra_conecctions    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# model                   0
# sim                     0
# additional_data       792
# 3G                     12
# 4G                     18
# 5G                     21
# Wi-Fi                  39
# VoLTE                 370
# Vo5G                  622
# NFC                   959
# extra_conecctions    1018
# dtype: int64

# %%
df
# Out:
#       Unnamed: 0                            model       sim additional_data  \
# 0              0                    OnePlus 11 5G  Dual Sim             NaN
# 1              1        OnePlus Nord CE 2 Lite 5G  Dual Sim             NaN
# 2              2            Samsung Galaxy A14 5G  Dual Sim             NaN
# 3              3             Motorola Moto G62 5G  Dual Sim             NaN
# 4              4               Realme 10 Pro Plus  Dual Sim             NaN
# ...          ...                              ...       ...             ...
# 1015        1015       Motorola Moto Edge S30 Pro  Dual Sim     No FM Radio
# 1016        1016                      Honor X8 5G  Dual Sim             NaN
# 1017        1017  POCO X4 GT 5G (8GB RAM + 256GB)  Dual Sim             NaN
# 1018        1018             Motorola Moto G91 5G  Dual Sim             NaN
# 1019        1019           Samsung Galaxy M52s 5G  Dual Sim             NaN
#
# ...

# %%
df = df.fillna('No data')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# model                0
# sim                  0
# additional_data      0
# 3G                   0
# 4G                   0
# 5G                   0
# Wi-Fi                0
# VoLTE                0
# Vo5G                 0
# NFC                  0
# extra_conecctions    0
# dtype: int64

# %%
df['3G'].unique()
# Out:
# array([' 3G', ' No Wifi', ' No 3G', 'No data', ' Wi-Fi', ' 4G',
#        ' No wifi'], dtype=object)

# %%
df[df['3G'].str.contains('WifI|Wi-Fi', case=False)]
# Out:
#      Unnamed: 0                          model         sim additional_data  \
# 532         532  Samsung Guru Music 2 Dual Sim    Dual Sim         No data
# 573         573               Nokia 105 (2019)  Single Sim         No data
# 685         685                   Xiaomi Qin 1    Dual Sim         No data
# 881         881               Nokia 110 (2022)    Dual Sim         No data
# 927         927             Samsung Guru E1200  Single Sim     No FM Radio
#
#            3G       4G       5G    Wi-Fi    VoLTE     Vo5G      NFC  \
# 532   No Wifi  No data  No data  No data  No data  No data  No data
# 573   No Wifi  No data  No data  No data  No data  No data  No data
# 685     Wi-Fi  No data  No data  No data  No data  No data  No data
# 881   No Wifi  No data  No data  No data  No data  No data  No data
# 927   No wifi  No data  No data  No data  No data  No data  No data
#
#     extra_conecctions
# 532           No data
# 573           No data
# 685           No data
# ...

# %%
sust = 'Wi-Fi'
# Recorrer la columna en busca de la palabra
for indice, valor in df['3G'].items():
    if sust in valor:
        df.at[indice, 'Wi-Fi'] = valor
        df.at[indice, '3G'] = 'No data'

# %%
df[df['3G'].str.contains('4g', case=False)]
# Out:
#      Unnamed: 0         model       sim        additional_data   3G      4G  \
# 748         748  Nokia 400 4G  Dual Sim  No FM Radio,Bluetooth   4G   VoLTE
#
#          5G    Wi-Fi    VoLTE     Vo5G      NFC extra_conecctions
# 748   Wi-Fi  No data  No data  No data  No data           No data

# %%
df.loc[748,'3G']= 'No data'
df.loc[748,'4G']= '4G'
df.loc[748,'5G']= 'No data'
df.loc[748,'Wi-Fi']= 'Wi-Fi'
df.loc[748,'VoLTE']= 'VoLTE'
df.loc[748,'extra_conecctions']= 'Bluetooth, No FM Radio'

# %%
df['4G'].unique()
# Out:
# array([' 4G', 'No data', ' Wi-Fi', '4G', ' No wifi'], dtype=object)

# %%
df[df['4G'].str.contains('wifi| wi-fi', case=False)]
# Out:
#       Unnamed: 0              model       sim additional_data      3G  \
# 608          608  Namotel Achhe Din  Dual Sim       Bluetooth      3G
# 735          735     Tecno Pop 5 Go  Dual Sim         No data      3G
# 1000        1000    XTouch F40 Flip  Dual Sim         No data   No 3G
#
#             4G       5G    Wi-Fi    VoLTE     Vo5G      NFC extra_conecctions
# 608      Wi-Fi  No data  No data  No data  No data  No data           No data
# 735      Wi-Fi  No data  No data  No data  No data  No data           No data
# 1000   No wifi  No data  No data  No data  No data  No data           No data

# %%
sust = '4G'
# Recorrer la columna en busca de la palabra
for indice, valor in df['4G'].items():
    if sust in valor:
        df.at[indice, '4G'] = '4G'  #damos los no data como no hay

# %%
df['5G'].unique()
# Out:
# array([' 5G', ' VoLTE', ' Wi-Fi', ' No Wifi', 'No data', ' No wifi'],
#       dtype=object)

# %%
df[df['5G'].str.contains('wifi| wi-fi', case=False)]
# Out:
#       Unnamed: 0                   model         sim additional_data   3G  4G  \
# 155          155         Nokia 2780 Flip    Dual Sim         No data   3G  4G
# 376          376         Nokia 2660 Flip    Dual Sim         No data   3G  4G
# 431          431   Vertu Signature Touch  Single Sim         No data   3G  4G
# 477          477                Vivo Y25    Dual Sim         No data   3G  4G
# 481          481            Itel A24 Pro    Dual Sim         No data   3G  4G
# 486          486           Nokia 8000 4G    Dual Sim         No data   3G  4G
# 582          582           Nokia 8210 4G    Dual Sim         No data   3G  4G
# 645          645         Nokia 2760 Flip    Dual Sim         No data   3G  4G
# 711          711          Gionee M12 Pro    Dual Sim         No data   3G  4G
# 734          734           Huawei Nova 9    Dual Sim     No FM Radio   3G  4G
# 857          857             LG Folder 2  Single Sim         No data   3G  4G
# ...

# %%
sust = 'Wi-Fi'
# Recorrer la columna en busca de la palabra
for indice, valor in df['5G'].items():
    if sust in valor:
        df.at[indice, 'NFC'] = df.at[indice, 'Wi-Fi']
        df.at[indice, 'Wi-Fi'] = valor
        df.at[indice, '5G'] = 'No data'

# %%
sust = 	'No wifi'
# Recorrer la columna en busca de la palabra
for indice, valor in df['5G'].items():
    if sust in valor:
        df.at[indice, 'Wi-Fi'] = valor
        df.at[indice, '5G'] = 'No data'

# %%
df[df['5G'].str.contains(' VoLTE', case=False)]
# Out:
#       Unnamed: 0                                    model       sim  \
# 16            16                                 Vivo Y16  Dual Sim
# 19            19                                 Vivo Y22  Dual Sim
# 33            33                          Apple iPhone 11  Dual Sim
# 44            44                                 Vivo Y35  Dual Sim
# 46            46                     Xiaomi Redmi Note 11  Dual Sim
# ...          ...                                      ...       ...
# 999          999                                Honor X7a  Dual Sim
# 1002        1002                               Doogee S99  Dual Sim
# 1003        1003                                  Lava X3  Dual Sim
# 1005        1005                                iKall Z18  Dual Sim
# 1010        1010  Realme Narzo 50i Prime (4GB RAM + 64GB)  Dual Sim
#
#      additional_data   3G  4G      5G   Wi-Fi        VoLTE     Vo5G      NFC  \
# ...

# %%
sust = ' VoLTE'
# Recorrer la columna en busca de la palabra
for indice, valor in df['5G'].items():
    if sust in valor:
        df.at[indice, 'extra_conecctions'] = df.at[indice, 'VoLTE']
        df.at[indice, 'VoLTE'] = valor
        df.at[indice, '5G'] = 'No data'

# %%
sust = ' 5G'
# Recorrer la columna en busca de la palabra
for indice, valor in df['5G'].items():
    if sust in valor:
       df.at[indice, '5G'] = '5G'

# %%
df.to_csv('df.csv')
