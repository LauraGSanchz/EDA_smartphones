# %% [markdown]
# # Análisis Exploratorio de Datos (EDA): SmartphoneMessy
#
#
# - Importación de las librerías necesarias.
# - Lectura y carga del conjunto de datos.
# - Exploración inicial de los datos.
# - Análisis de la cardinalidad de las variables.
# - Tratamiento de valores faltantes y anomalías. Se puede optar por separar los datos en dos dataframes, especialmente para segmentar según las NaNs en la columna 'rating'.
# - Por ejemplo, convertir los precios a euros, separar la información en la columna 'sim', procesar la columna 'ram', etc.
# - Exploración de cada columna individualmente.: Estudio de las relaciones entre las variables más relevantes y la variable objetivo ('Rating').
# - Utilizar el modelo OLS de Statsmodels

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib as plt
import sklearn as sk
import scipy.stats as stats
pd.set_option('display.max_columns', None)

# %%
smartphones = pd.read_csv(r'C:\Users\laura\OneDrive\Desktop\EDA_smartphones\smartphonesmessy.csv')

# %% [markdown]
# ## Análisis inicial de datos

# %%
smartphones.shape
# Out:
# (1020, 11)

# %%
smartphones.size
# Out:
# 11220

# %%
smartphones.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
smartphones.tail()
# Out:
#                                 model    price  rating  \
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                            processor  \
# 1015   Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016  Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017   Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018    Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                             Octa Core Processor
#
#                            ram                                    battery  \
# 1015  8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016  6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017  8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018  6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019  8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera  \
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12

# %%
smartphones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
smartphones.dtypes
# Out:
# model         object
# price         object
# rating       float64
# sim           object
# processor     object
# ram           object
# battery       object
# display       object
# camera        object
# card          object
# os            object
# dtype: object

# %%
smartphones.duplicated().sum()
# Out:
# 0

# %%
smartphones.isna().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %%
smartphones.describe(include=object)
# Out:
#                 model    price                             sim  \
# count            1020     1020                            1020
# unique           1020      412                              28
# top     OnePlus 11 5G  ₹14,999  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# freq                1       21                             324
#
#                                              processor  \
# count                                             1020
# unique                                             298
# top     Dimensity 700 5G, Octa Core, 2.2 GHz Processor
# freq                                                29
#
#                              ram                                  battery  \
# count                       1020                                     1020
# unique                        58                                      256
# top     8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 33W Fast Charging
# freq                         267                                      103
#
#                                                   display  \
# count                                                1020
# unique                                                369
# top     6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# freq                                                   54
#
#                                                    camera  \
# count                                                1019
# unique                                                285
# top     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# freq                                                   40
#
#                                     card           os
# count                               1013         1003
# unique                                63           48
# top     Memory Card Supported, upto 1 TB  Android v12
# freq                                 171          287

# %%
smartphones.describe().round(2)
# Out:
#        rating
# count  879.00
# mean    78.26
# std      7.40
# min     60.00
# 25%     74.00
# 50%     80.00
# 75%     84.00
# max     89.00

# %% [markdown]
# ## Cambio divisa

# %%
smartphones = smartphones.rename(columns={'price':'indian_rupee_price' })

# %%
smartphones['indian_rupee_price'] = smartphones['indian_rupee_price'].map(lambda x: x.lstrip('₹'))

# %%
smartphones['indian_rupee_price'] = smartphones['indian_rupee_price'].str.replace(',', '')

# %%
smartphones['indian_rupee_price'] = pd.to_numeric(smartphones['indian_rupee_price'])

# %%
smartphones['euro_price'] = (smartphones['indian_rupee_price']/91.683929).round(2)

# %%
cols = smartphones.columns.to_list()

# %%
smartphones = smartphones[['model',
 'euro_price',
 'indian_rupee_price',
 'rating',
 'sim',
 'processor',
 'ram',
 'battery',
 'display',
 'camera',
 'card',
 'os']]

# %%
smartphones.dtypes
# Out:
# model                  object
# euro_price            float64
# indian_rupee_price      int64
# rating                float64
# sim                    object
# processor              object
# ram                    object
# battery                object
# display                object
# camera                 object
# card                   object
# os                     object
# dtype: object

# %% [markdown]
# ## Sustitución NaN

# %%
smartphones[smartphones['os'].isna()]
# Out:
#                              model  euro_price  indian_rupee_price  rating  \
# 473                   Nokia 110 4G       19.22                1762     NaN
# 532  Samsung Guru Music 2 Dual Sim       21.26                1949     NaN
# 573               Nokia 105 (2019)       14.17                1299     NaN
# 608              Namotel Achhe Din        1.08                  99     NaN
# 640                 Nokia 105 Plus       14.17                1299     NaN
# 645                Nokia 2760 Flip       59.88                5490     NaN
# 647              Motorola Moto A10       14.60                1339     NaN
# 657                  Zanco Tiny T1       30.53                2799     NaN
# 665                   itel it2163S       10.45                 958     NaN
# 699          Samsung Guru GT-E1215       20.18                1850     NaN
# 748                   Nokia 400 4G       35.88                3290     NaN
# 757                   Karbonn KU3i       10.85                 995     NaN
# 835                 Eunity U1 King        6.53                 599     NaN
# 857                    LG Folder 2      130.87               11999     NaN
# 881               Nokia 110 (2022)       17.44                1599     NaN
# 927             Samsung Guru E1200       18.38                1685     NaN
# 932                 Eunity U1 Livo        7.08                 649     NaN
#
#                             sim                 processor  \
# 473     Dual Sim, 3G, 4G, VoLTE                   No Wifi
# 532                    Dual Sim                   No Wifi
# 573                  Single Sim                   No Wifi
# 608         Dual Sim, 3G, Wi-Fi    1 GB RAM, 4 GB inbuilt
# 640                    Dual Sim    4 MB RAM, 4 MB inbuilt
# 645     Dual Sim, 3G, 4G, Wi-Fi          1450 mAh Battery
# 647                    Dual Sim    4 MB RAM, 4 MB inbuilt
# 657                  Single Sim  32 MB RAM, 32 MB inbuilt
# 665                    Dual Sim    4 MB RAM, 4 MB inbuilt
# 699                  Single Sim           800 mAh Battery
# 748  Dual Sim, 4G, VoLTE, Wi-Fi          2000 mAh Battery
# 757                    Dual Sim  52 MB RAM, 32 MB inbuilt
# 835                    Dual Sim        1.77 MHz Processor
# 857   Single Sim, 3G, 4G, Wi-Fi    1 GB RAM, 8 GB inbuilt
# 881                    Dual Sim                   No Wifi
# 927                  Single Sim                   No Wifi
# 932                    Dual Sim        1.77 MHz Processor
#
#                                   ram                            battery  \
# 473         128 MB RAM, 48 MB inbuilt                   1020 mAh Battery
# 532    Single Core, 208 MHz Processor                    800 mAh Battery
# 573            4 MB RAM, 4 MB inbuilt                    800 mAh Battery
# 608                  1325 mAh Battery    4 inches, 720 x 1280 px Display
# 640                   800 mAh Battery  1.77 inches, 128 x 160 px Display
# 645  3.6 inches, 240 x 320 px Display      5 MP Rear & 5 MP Front Camera
# 647                  1750 mAh Battery   1.8 inches, 160 x 128 px Display
# 657                   200 mAh Battery    0.49 inches, 64 x 32 px Display
# 665                  1200 mAh Battery   1.8 inches, 160 x 128 px Display
# 699  1.5 inches, 120 x 120 px Display                     No Rear Camera
# 748  2.4 inches, 240 x 320 px Display  0.3 MP Rear & 0.3 MP Front Camera
# 757                  1000 mAh Battery   1.8 inches, 128 x 160 px Display
# 835          32 MB RAM, 32 MB inbuilt                   1000 mAh Battery
# 857                  1470 mAh Battery   2.8 inches, 240 x 320 px Display
# 881            4 MB RAM, 4 MB inbuilt                   1000 mAh Battery
# 927                   800 mAh Battery   1.5 inches, 128 x 128 px Display
# 932          16 MB RAM, 16 MB inbuilt                   1000 mAh Battery
#
#                                display                             camera  \
# 473   1.8 inches, 120 x 160 px Display                 0.3 MP Rear Camera
# 532     2 inches, 128 x 160 px Display                     No Rear Camera
# 573  1.77 inches, 120 x 160 px Display                     No Rear Camera
# 608    2 MP Rear & 0.3 MP Front Camera            Android v5.0 (Lollipop)
# 640                     No Rear Camera  Memory Card Supported, upto 32 GB
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0
# 647                     No Rear Camera  Memory Card Supported, upto 32 GB
# 657                     No Rear Camera                        No FM Radio
# 665                     No Rear Camera  Memory Card Supported, upto 32 GB
# 699                        No FM Radio                                NaN
# 748  Memory Card Supported, upto 64 GB                          Bluetooth
# 757                     No Rear Camera  Memory Card Supported, upto 16 GB
# 835   1.8 inches, 260 x 240 px Display                 0.3 MP Rear Camera
# 857                   2 MP Rear Camera              Memory Card Supported
# 881  1.77 inches, 120 x 160 px Display  Memory Card Supported, upto 32 GB
# 927                     No Rear Camera                        No FM Radio
# 932   1.8 inches, 280 x 240 px Display                 0.3 MP Rear Camera
#
#                                   card   os
# 473  Memory Card Supported, upto 32 GB  NaN
# 532  Memory Card Supported, upto 16 GB  NaN
# 573                                NaN  NaN
# 608                          Bluetooth  NaN
# 640                          Bluetooth  NaN
# 645                          Bluetooth  NaN
# 647                                NaN  NaN
# 657                          Bluetooth  NaN
# 665                          Bluetooth  NaN
# 699                                NaN  NaN
# 748                            Browser  NaN
# 757                          Bluetooth  NaN
# 835                                NaN  NaN
# 857                          Bluetooth  NaN
# 881                                NaN  NaN
# 927                                NaN  NaN
# 932                                NaN  NaN

# %%
smartphones[smartphones['model'].str.contains('Samsung Guru')]
# Out:
#                              model  euro_price  indian_rupee_price  rating  \
# 532  Samsung Guru Music 2 Dual Sim       21.26                1949     NaN
# 699          Samsung Guru GT-E1215       20.18                1850     NaN
# 927             Samsung Guru E1200       18.38                1685     NaN
#
#             sim        processor                               ram  \
# 532    Dual Sim          No Wifi    Single Core, 208 MHz Processor
# 699  Single Sim  800 mAh Battery  1.5 inches, 120 x 120 px Display
# 927  Single Sim          No Wifi                   800 mAh Battery
#
#                               battery                         display  \
# 532                   800 mAh Battery  2 inches, 128 x 160 px Display
# 699                    No Rear Camera                     No FM Radio
# 927  1.5 inches, 128 x 128 px Display                  No Rear Camera
#
#              camera                               card   os
# 532  No Rear Camera  Memory Card Supported, upto 16 GB  NaN
# 699             NaN                                NaN  NaN
# 927     No FM Radio                                NaN  NaN

# %%
# los datos en esta fila estaban mal organizados

value = smartphones.at[699, 'camera']
if isinstance(value, float):
    value = str(value)

# %%
value = smartphones.loc[699, 'camera']
if value == 'nan':
    smartphones.loc[699, 'camera'] = 'No Rear Camera'

# %%
smartphones.loc[699, 'display'] = '1.5 inches, 120 x 120 px Display	'
smartphones.loc[699, 'battery']= '800 mAh Battery'
smartphones.loc[699, 'os']= 'No FM Radio'
smartphones.loc[881, 'card']= 'Memory Card Supported, upto 32 GB'

# %%
#Encontramos que los valores de la fila están desplazados a la izquierda una posición.
valores_fila = smartphones.loc[647].tolist()

# %%
valores_fila = ['Motorola Moto A10',
 14.6,
 1339,
 'NaN',
 'Dual Sim',
 'nan',
 '4\u2009MB RAM, 4\u2009MB inbuilt',
 '1750\u2009mAh Battery',
 '1.8 inches, 160\u2009x\u2009128\u2009px Display',
 'No Rear Camera',
 'Memory Card Supported, upto 32\u2009GB',
 'nan']

# %%
smartphones.loc[647] = valores_fila
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_2852\2056221463.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'NaN' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   smartphones.loc[647] = valores_fila

# %%
valores_fila2 = smartphones.loc[927].tolist()
valores_fila2 = ['Samsung Guru E1200',
 18.38,
 1685,
 'nan',
 'Single Sim',
 'No Wifi',
 'nan',
 '800\u2009mAh Battery',
 '1.5 inches, 128\u2009x\u2009128\u2009px Display',
 'No Rear Camera',
 'nan',
 'No FM Radio']

# %%
smartphones.loc[927] = valores_fila2

# %%
smartphones[smartphones['os'].isna()]
# Out:
#                              model  euro_price  indian_rupee_price rating  \
# 473                   Nokia 110 4G       19.22                1762    NaN
# 532  Samsung Guru Music 2 Dual Sim       21.26                1949    NaN
# 573               Nokia 105 (2019)       14.17                1299    NaN
# 608              Namotel Achhe Din        1.08                  99    NaN
# 640                 Nokia 105 Plus       14.17                1299    NaN
# 645                Nokia 2760 Flip       59.88                5490    NaN
# 657                  Zanco Tiny T1       30.53                2799    NaN
# 665                   itel it2163S       10.45                 958    NaN
# 748                   Nokia 400 4G       35.88                3290    NaN
# 757                   Karbonn KU3i       10.85                 995    NaN
# 835                 Eunity U1 King        6.53                 599    NaN
# 857                    LG Folder 2      130.87               11999    NaN
# 881               Nokia 110 (2022)       17.44                1599    NaN
# 932                 Eunity U1 Livo        7.08                 649    NaN
#
#                             sim                 processor  \
# 473     Dual Sim, 3G, 4G, VoLTE                   No Wifi
# 532                    Dual Sim                   No Wifi
# 573                  Single Sim                   No Wifi
# 608         Dual Sim, 3G, Wi-Fi    1 GB RAM, 4 GB inbuilt
# 640                    Dual Sim    4 MB RAM, 4 MB inbuilt
# 645     Dual Sim, 3G, 4G, Wi-Fi          1450 mAh Battery
# 657                  Single Sim  32 MB RAM, 32 MB inbuilt
# 665                    Dual Sim    4 MB RAM, 4 MB inbuilt
# 748  Dual Sim, 4G, VoLTE, Wi-Fi          2000 mAh Battery
# 757                    Dual Sim  52 MB RAM, 32 MB inbuilt
# 835                    Dual Sim        1.77 MHz Processor
# 857   Single Sim, 3G, 4G, Wi-Fi    1 GB RAM, 8 GB inbuilt
# 881                    Dual Sim                   No Wifi
# 932                    Dual Sim        1.77 MHz Processor
#
#                                   ram                            battery  \
# 473         128 MB RAM, 48 MB inbuilt                   1020 mAh Battery
# 532    Single Core, 208 MHz Processor                    800 mAh Battery
# 573            4 MB RAM, 4 MB inbuilt                    800 mAh Battery
# 608                  1325 mAh Battery    4 inches, 720 x 1280 px Display
# 640                   800 mAh Battery  1.77 inches, 128 x 160 px Display
# 645  3.6 inches, 240 x 320 px Display      5 MP Rear & 5 MP Front Camera
# 657                   200 mAh Battery    0.49 inches, 64 x 32 px Display
# 665                  1200 mAh Battery   1.8 inches, 160 x 128 px Display
# 748  2.4 inches, 240 x 320 px Display  0.3 MP Rear & 0.3 MP Front Camera
# 757                  1000 mAh Battery   1.8 inches, 128 x 160 px Display
# 835          32 MB RAM, 32 MB inbuilt                   1000 mAh Battery
# 857                  1470 mAh Battery   2.8 inches, 240 x 320 px Display
# 881            4 MB RAM, 4 MB inbuilt                   1000 mAh Battery
# 932          16 MB RAM, 16 MB inbuilt                   1000 mAh Battery
#
#                                display                             camera  \
# 473   1.8 inches, 120 x 160 px Display                 0.3 MP Rear Camera
# 532     2 inches, 128 x 160 px Display                     No Rear Camera
# 573  1.77 inches, 120 x 160 px Display                     No Rear Camera
# 608    2 MP Rear & 0.3 MP Front Camera            Android v5.0 (Lollipop)
# 640                     No Rear Camera  Memory Card Supported, upto 32 GB
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0
# 657                     No Rear Camera                        No FM Radio
# 665                     No Rear Camera  Memory Card Supported, upto 32 GB
# 748  Memory Card Supported, upto 64 GB                          Bluetooth
# 757                     No Rear Camera  Memory Card Supported, upto 16 GB
# 835   1.8 inches, 260 x 240 px Display                 0.3 MP Rear Camera
# 857                   2 MP Rear Camera              Memory Card Supported
# 881  1.77 inches, 120 x 160 px Display  Memory Card Supported, upto 32 GB
# 932   1.8 inches, 280 x 240 px Display                 0.3 MP Rear Camera
#
#                                   card   os
# 473  Memory Card Supported, upto 32 GB  NaN
# 532  Memory Card Supported, upto 16 GB  NaN
# 573                                NaN  NaN
# 608                          Bluetooth  NaN
# 640                          Bluetooth  NaN
# 645                          Bluetooth  NaN
# 657                          Bluetooth  NaN
# 665                          Bluetooth  NaN
# 748                            Browser  NaN
# 757                          Bluetooth  NaN
# 835                                NaN  NaN
# 857                          Bluetooth  NaN
# 881  Memory Card Supported, upto 32 GB  NaN
# 932                                NaN  NaN

# %%
smartphones[smartphones['card'].str.contains('No Wifi')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 smartphones[smartphones['card'].str.contains('No Wifi')]
#
# File c:\Users\laura\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3886, in DataFrame.__getitem__(self, key)
#    3883     return self.where(key)
#    3885 # Do we have a (boolean) 1d indexer?
# -> 3886 if com.is_bool_indexer(key):
#    3887     return self._getitem_bool_array(key)
#    3889 # We are left with two options: a single key, and a collection of keys,
#    3890 # We interpret tuples as collections only for non-MultiIndex
#
# File c:\Users\laura\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\common.py:133, in is_bool_indexer(key)
#     129     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     130     if lib.is_bool_array(key_array, skipna=True):
#     131         # Don't raise on e.g. ["A", "B", np.nan], see
#     132         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 133         raise ValueError(na_msg)
#     134     return False
#     135 return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
# rellenamos el resto con not found 
smartphones['card'].fillna('not found', inplace=True)
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_11112\815947258.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartphones['card'].fillna('not found', inplace=True)

# %%
smartphones.isna().sum()
# Out:
# model                   0
# euro_price              0
# indian_rupee_price      0
# rating                139
# sim                     0
# processor               0
# ram                     0
# battery                 0
# display                 0
# camera                  0
# card                    0
# os                     14
# dtype: int64

# %%
values = smartphones.loc[757].to_list()
values
# Out:
# ['Karbonn KU3i',
#  10.85,
#  995,
#  nan,
#  'Dual Sim',
#  '52\u2009MB RAM, 32\u2009MB inbuilt',
#  '1000\u2009mAh Battery',
#  '1.8 inches, 128\u2009x\u2009160\u2009px Display',
#  'No Rear Camera',
#  'Memory Card Supported, upto 16\u2009GB',
#  'Bluetooth',
#  nan]

# %%
smartphones.loc[757] = ['Karbonn KU3i',
 10.85,
 995,
'nan',
 'Dual Sim',
 'nan',
 '52\u2009MB RAM, 32\u2009MB inbuilt',
 '1000\u2009mAh Battery',
 '1.8 inches, 128\u2009x\u2009160\u2009px Display',
 'No Rear Camera',
 'Memory Card Supported, upto 16\u2009GB',
 'Bluetooth']

# %%
smartphones[smartphones['os'].isna()]
# Out:
#                              model  euro_price  indian_rupee_price rating  \
# 473                   Nokia 110 4G       19.22                1762    NaN
# 532  Samsung Guru Music 2 Dual Sim       21.26                1949    NaN
# 573               Nokia 105 (2019)       14.17                1299    NaN
# 748                   Nokia 400 4G       35.88                3290    NaN
# 835                 Eunity U1 King        6.53                 599    NaN
# 881               Nokia 110 (2022)       17.44                1599    NaN
# 932                 Eunity U1 Livo        7.08                 649    NaN
#
#                             sim           processor  \
# 473     Dual Sim, 3G, 4G, VoLTE             No Wifi
# 532                    Dual Sim             No Wifi
# 573                  Single Sim             No Wifi
# 748  Dual Sim, 4G, VoLTE, Wi-Fi    2000 mAh Battery
# 835                    Dual Sim  1.77 MHz Processor
# 881                    Dual Sim             No Wifi
# 932                    Dual Sim  1.77 MHz Processor
#
#                                   ram                            battery  \
# 473         128 MB RAM, 48 MB inbuilt                   1020 mAh Battery
# 532    Single Core, 208 MHz Processor                    800 mAh Battery
# 573            4 MB RAM, 4 MB inbuilt                    800 mAh Battery
# 748  2.4 inches, 240 x 320 px Display  0.3 MP Rear & 0.3 MP Front Camera
# 835          32 MB RAM, 32 MB inbuilt                   1000 mAh Battery
# 881            4 MB RAM, 4 MB inbuilt                   1000 mAh Battery
# 932          16 MB RAM, 16 MB inbuilt                   1000 mAh Battery
#
#                                display                             camera  \
# 473   1.8 inches, 120 x 160 px Display                 0.3 MP Rear Camera
# 532     2 inches, 128 x 160 px Display                     No Rear Camera
# 573  1.77 inches, 120 x 160 px Display                     No Rear Camera
# 748  Memory Card Supported, upto 64 GB                          Bluetooth
# 835   1.8 inches, 260 x 240 px Display                 0.3 MP Rear Camera
# 881  1.77 inches, 120 x 160 px Display  Memory Card Supported, upto 32 GB
# 932   1.8 inches, 280 x 240 px Display                 0.3 MP Rear Camera
#
#                                   card   os
# 473  Memory Card Supported, upto 32 GB  NaN
# 532  Memory Card Supported, upto 16 GB  NaN
# 573                          not found  NaN
# 748                            Browser  NaN
# 835                          not found  NaN
# 881  Memory Card Supported, upto 32 GB  NaN
# 932                          not found  NaN

# %%
# los datos en esta fila estaban mal organizados
# Kaios v3.0 DONDE VA???
smartphones.loc[748, 'display'] = '2.4 inches, 240 x 320 px Display'
smartphones.loc[748, 'battery']= '2000 mAh Battery'
smartphones.loc[748, 'os']= 'Bluetooth'
smartphones.loc[748, 'card']= 'Memory Card Supported, upto 64 GB'
smartphones.loc[748, 'camera']= '0.3 MP Rear & 0.3 MP Front Camera'
smartphones.loc[748, 'processor'] ='NaN'

# %%
smartphones['os'].fillna(value='no data', inplace=True)
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_11112\1484829204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartphones['os'].fillna(value='no data', inplace=True)

# %%
smartphones[smartphones['os'].isna()]
# Out:
# Empty DataFrame
# Columns: [model, euro_price, indian_rupee_price, rating, sim, processor, ram, battery, display, camera, card, os]
# Index: []

# %% [markdown]
# ### Imputación NaN en la columna rating

# %%
smartphones.isna().sum()
# Out:
# model                   0
# euro_price              0
# indian_rupee_price      0
# rating                133
# sim                     0
# processor               0
# ram                     0
# battery                 0
# display                 0
# camera                  0
# card                    0
# os                      0
# dtype: int64

# %%
smartphones['rating'] = smartphones['rating'].astype(float)

# %%
print(smartphones['rating'].mean().round(2))
print(smartphones['rating'].median())
print(smartphones['rating'].mode())
# Out:
# 78.26
# 80.0
# 0    84.0
# Name: rating, dtype: float64

# %%
from sklearn.impute import KNNImputer

# %%
# cpnstrucción del modelo
imputer = KNNImputer()

# Ajustamos el modelo e imputamos los missing values
imputer.fit(smartphones[["rating"]])
smartphones["rating"] = imputer.transform(smartphones[["rating"]])

# %%
smartphones.isna().sum()
# Out:
# model                 0
# euro_price            0
# indian_rupee_price    0
# rating                0
# sim                   0
# processor             0
# ram                   0
# battery               0
# display               0
# camera                0
# card                  0
# os                    0
# dtype: int64

# %% [markdown]
# ## Limpieza columna ram

# %%
smartphones['ram'].unique()
# Out:
# array(['12\u2009GB RAM, 256\u2009GB inbuilt',
#        '6\u2009GB RAM, 128\u2009GB inbuilt',
#        '4\u2009GB RAM, 64\u2009GB inbuilt',
#        '8\u2009GB RAM, 256\u2009GB inbuilt',
#        '8\u2009GB RAM, 128\u2009GB inbuilt',
#        '4\u2009GB RAM, 128\u2009GB inbuilt',
#        '3\u2009GB RAM, 32\u2009GB inbuilt',
#        '16\u2009GB RAM, 256\u2009GB inbuilt',
#        '6\u2009GB RAM, 64\u2009GB inbuilt',
#        '4\u2009GB RAM, 32\u2009GB inbuilt',
#        '3\u2009GB RAM, 64\u2009GB inbuilt',
#        '2\u2009GB RAM, 32\u2009GB inbuilt',
#        '16\u2009GB RAM, 512\u2009GB inbuilt',
#        '2\u2009GB RAM, 64\u2009GB inbuilt',
#        '4\u2009GB RAM, 512\u2009MB inbuilt',
#        '6\u2009GB RAM, 256\u2009GB inbuilt',
#        '12\u2009GB RAM, 128\u2009GB inbuilt',
#        '512\u2009MB RAM, 4\u2009GB inbuilt',
#        '18\u2009GB RAM, 512\u2009GB inbuilt',
#        '6\u2009GB RAM, 1\u2009TB inbuilt',
#        '12\u2009GB RAM, 512\u2009GB inbuilt',
#        '4\u2009GB RAM, 256\u2009GB inbuilt', 'Unisoc T107',
#        '1\u2009GB RAM, 16\u2009GB inbuilt',
#        '18\u2009GB RAM, 256\u2009GB inbuilt', '64\u2009GB inbuilt',
#        '128\u2009MB RAM, 48\u2009MB inbuilt', '512\u2009GB inbuilt',
#        'Single Core, 208\u2009MHz Processor',
#        '64\u2009MB RAM, 128\u2009MB inbuilt', 'T117',
#        '4\u2009MB RAM, 4\u2009MB inbuilt',
#        '3\u2009GB RAM, 16\u2009GB inbuilt',
#        '1\u2009GB RAM, 8\u2009GB inbuilt',
#        '1\u2009GB RAM, 4\u2009GB inbuilt',
#        'Dual Core, 500\u2009MHz Processor',
#        '6\u2009GB RAM, 512\u2009GB inbuilt',
#        '3.6 inches, 240\u2009x\u2009320\u2009px Display',
#        '32\u2009MB RAM, 32\u2009MB inbuilt',
#        '8\u2009MB RAM, 16\u2009MB inbuilt',
#        '1.5 inches, 120\u2009x\u2009120\u2009px Display',
#        '8\u2009GB RAM, 512\u2009GB inbuilt',
#        '2\u2009GB RAM, 16\u2009GB inbuilt',
#        '2.4 inches, 240\u2009x\u2009320\u2009px Display',
#        '4 inches, 640\u2009x\u20091136\u2009px Display',
#        '52\u2009MB RAM, 32\u2009MB inbuilt',
#        '4\u2009GB RAM, 512\u2009GB inbuilt',
#        '48\u2009MB RAM, 48\u2009MB inbuilt', '4\u2009MB inbuilt',
#        '1200\u2009mAh Battery', 'nan', '1800\u2009mAh Battery',
#        '16\u2009MB RAM, 16\u2009MB inbuilt',
#        '12\u2009GB RAM, 1\u2009TB inbuilt', 'No Wifi'], dtype=object)

# %%
# continuar aquí modficando valores de las columnas
smartphones[smartphones['ram'].str.contains('display', case=False)]
# Out:
#                           model  euro_price  indian_rupee_price     rating  \
# 645             Nokia 2760 Flip       59.88                5490  78.258248
# 699       Samsung Guru GT-E1215       20.18                1850  78.258248
# 754  Apple iPod Touch (7th Gen)      206.14               18900  78.258248
#
#                          sim         processor  \
# 645  Dual Sim, 3G, 4G, Wi-Fi  1450 mAh Battery
# 699               Single Sim   800 mAh Battery
# 754                    Wi-Fi     32 GB inbuilt
#
#                                   ram                          battery  \
# 645  3.6 inches, 240 x 320 px Display                 1450 mAh Battery
# 699  1.5 inches, 120 x 120 px Display                  800 mAh Battery
# 754   4 inches, 640 x 1136 px Display  8 MP Rear & 1.2 MP Front Camera
#
#                                 display                         camera  \
# 645    3.6 inches, 240 x 320 px Display  5 MP Rear & 5 MP Front Camera
# 699  1.5 inches, 120 x 120 px Display\t                 No Rear Camera
# 754                             iOS v12                    No FM Radio
#
#                                   card           os
# 645  Memory Card Supported, upto 32 GB    Bluetooth
# 699                          not found  No FM Radio
# 754                          Bluetooth      Browser

# %%
smartphones.loc[748, 'display'] = '2.4 inches, 240 x 320 px Display'
smartphones.loc[748, 'battery']= '2000 mAh Battery'
smartphones.loc[748, 'os']= 'Bluetooth'
smartphones.loc[748, 'card']= 'Memory Card Supported, upto 64 GB'
smartphones.loc[748, 'camera']= '0.3 MP Rear & 0.3 MP Front Camera'
smartphones.loc[748, 'processor'] ='NaN'
smartphones.loc[748, 'ram'] ='Not found'

# %%
smartphones.loc[754, 'display'] = '4 inches, 640 x 1136 px Display'
smartphones.loc[754, 'battery']= 'Not found'

smartphones.loc[754, 'card']= 'iOS v12'
smartphones.loc[754, 'camera']= '8 MP Rear & 1.2 MP Front Camera'

smartphones.loc[754, 'ram'] ='Not found'
smartphones.loc[748, 'os']= 'No FM Radio,Bluetooth, Browser'  #NO SE CAMBIA, ¿POR QUÉ?

# %%
smartphones.loc[754,:]
# Out:
# model                      Apple iPod Touch (7th Gen)
# euro_price                                     206.14
# indian_rupee_price                              18900
# rating                                      78.258248
# sim                                             Wi-Fi
# processor                               32 GB inbuilt
# ram                                         Not found
# battery                                     Not found
# display               4 inches, 640 x 1136 px Display
# camera                8 MP Rear & 1.2 MP Front Camera
# card                                          iOS v12
# os                                            Browser
# Name: 754, dtype: object

# %%
smartphones[smartphones['ram'].str.contains('display', case=False)]
# Out:
#                      model  euro_price  indian_rupee_price     rating  \
# 645        Nokia 2760 Flip       59.88                5490  78.258248
# 699  Samsung Guru GT-E1215       20.18                1850  78.258248
#
#             sim        processor                               ram  \
# 645   Not found        Not found  3.6 inches, 240 x 320 px Display
# 699  Single Sim  800 mAh Battery  1.5 inches, 120 x 120 px Display
#
#               battery                             display  \
# 645  1450 mAh Battery    3.6 inches, 240 x 320 px Display
# 699   800 mAh Battery  1.5 inches, 120 x 120 px Display\t
#
#                             camera                               card  \
# 645  5 MP Rear & 5 MP Front Camera  Memory Card Supported, upto 32 GB
# 699                 No Rear Camera                          not found
#
#               os
# 645    Bluetooth
# 699  No FM Radio

# %%
smartphones.loc[699, 'ram']='Not found'
smartphones.loc[699, 'processor'] ='Not found'
smartphones.loc[699,'sim'] = 'Single Sim'

# %%
smartphones[smartphones['ram'].str.contains('Battery')]
# Out:
#                    model  euro_price  indian_rupee_price     rating  \
# 925        Nokia 3310 4G       43.62                3999  78.258248
# 930     iKall K88 Pro 4G       22.89                2099  78.258248
# 988  Nokia 5310 Dual Sim       37.07                3399  78.258248
#
#                                 sim                   processor  \
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
# 930         Dual Sim, 3G, 4G, VoLTE   48 MB RAM, 128 MB inbuilt
# 988                        Dual Sim     8 MB RAM, 16 MB inbuilt
#
#                   ram                           battery             display  \
# 925  1200 mAh Battery  2.4 inches, 240 x 320 px Display    2 MP Rear Camera
# 930  1800 mAh Battery  2.4 inches, 240 x 360 px Display  0.3 MP Rear Camera
# 988  1200 mAh Battery  2.4 inches, 240 x 320 px Display  0.3 MP Rear Camera
#
#                                  camera       card       os
# 925   Memory Card Supported, upto 32 GB  Bluetooth  Browser
# 930  Memory Card Supported, upto 128 GB  Bluetooth  Browser
# 988   Memory Card Supported, upto 32 GB  Bluetooth  Browser

# %%
valores_ram = smartphones.loc[1000].tolist()
valores_ram
# Out:
# ['XTouch F40 Flip',
#  21.8,
#  1999,
#  78.25824800910125,
#  'Dual Sim',
#  'No 3G',
#  'No Wifi',
#  '32\u2009MB RAM, 32\u2009MB inbuilt',
#  '800\u2009mAh Battery',
#  '1.77 inches, 240\u2009x\u2009320\u2009px Display',
#  'Dual Display',
#  '1.3\u2009MP Rear Camera']

# %%
valores_ram = ['XTouch F40 Flip',
 21.8,
 1999,
 78.25824800910125,
 'Dual Sim, No 3G, No wifi',
 '32\u2009MB RAM, 32\u2009MB inbuilt',
 'Not found',
 '800\u2009mAh Battery',
 '1.77 inches, 240\u2009x\u2009320\u2009px Display',
 '1.3\u2009MP Rear Camera',
'Dual Display', 
'Not found']
smartphones.loc[1000] = valores_ram

# %%
smartphones.loc[927, 'ram'] ='Not found'  #habíamos puesto Nan con anterioridad

# %%
smartphones[smartphones['ram'].str.contains('No wifi', case=False)]  #se cambia con el codigo de arriba
# Out:
#                 model  euro_price  indian_rupee_price     rating       sim  \
# 1000  XTouch F40 Flip        21.8                1999  78.258248  Dual Sim
#
#      processor      ram                   battery          display  \
# 1000     No 3G  No Wifi  32 MB RAM, 32 MB inbuilt  800 mAh Battery
#
#                                  camera          card                  os
# 1000  1.77 inches, 240 x 320 px Display  Dual Display  1.3 MP Rear Camera

# %% [markdown]
# ## Análisis de cardinalidad

# %%
cardinalidad= pd.DataFrame(columns=['cardinalidad','porcentaje_cardinalidad','tipo_de_dato','valores_unicos'],  index=smartphones.columns)

# %%
cardinalidad['cardinalidad']= [smartphones[col].nunique() for col in smartphones.columns]
cardinalidad['porcentaje_cardinalidad'] = (cardinalidad['cardinalidad']/len(smartphones)*100).round(2)
cardinalidad['tipo_de_dato'] = smartphones.dtypes
cardinalidad['valores_unicos'] = [smartphones[col].unique() for col in smartphones.columns]

# %%
cardinalidad
# Out:
#                     cardinalidad  porcentaje_cardinalidad tipo_de_dato  \
# model                       1020                   100.00       object
# euro_price                   412                    40.39      float64
# indian_rupee_price           412                    40.39        int64
# rating                        31                     3.04      float64
# sim                           28                     2.75       object
# processor                    294                    28.82       object
# ram                           55                     5.39       object
# battery                      251                    24.61       object
# display                      372                    36.47       object
# camera                       281                    27.55       object
# card                          65                     6.37       object
# os                            51                     5.00       object
#
#                                                        valores_unicos
# model               [OnePlus 11 5G, OnePlus Nord CE 2 Lite 5G, Sam...
# euro_price          [599.88, 218.02, 179.96, 163.59, 272.67, 185.4...
# indian_rupee_price  [54999, 19989, 16499, 14999, 24999, 16999, 659...
# rating              [89.0, 81.0, 75.0, 82.0, 80.0, 86.0, 85.0, 84....
# sim                 [Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, Dual...
# processor           [Snapdragon 8 Gen2, Octa Core, 3.2 GHz Process...
# ram                 [12 GB RAM, 256 GB inbuilt, 6 GB RAM, 128 GB i...
# battery             [5000 mAh Battery with 100W Fast Charging, 500...
# display             [6.7 inches, 1440 x 3216 px, 120 Hz Display wi...
# camera              [50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fro...
# card                [Memory Card Not Supported, Memory Card (Hybri...
# os                  [Android v13, Android v12, iOS v16, No FM Radi...

# %% [markdown]
# ## Análisis Univariante

# %%
smartphones
# Out:
#                                 model  euro_price  indian_rupee_price  rating  \
# 0                       OnePlus 11 5G      599.88               54999    89.0
# 1           OnePlus Nord CE 2 Lite 5G      218.02               19989    81.0
# 2               Samsung Galaxy A14 5G      179.96               16499    75.0
# 3                Motorola Moto G62 5G      163.59               14999    81.0
# 4                  Realme 10 Pro Plus      272.67               24999    82.0
# ...                               ...         ...                 ...     ...
# 1015       Motorola Moto Edge S30 Pro      381.64               34990    83.0
# 1016                      Honor X8 5G      163.50               14990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)      316.20               28990    85.0
# 1018             Motorola Moto G91 5G      218.03               19990    80.0
# 1019           Samsung Galaxy M52s 5G      272.57               24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery  \
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera  \
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [1020 rows x 12 columns]
